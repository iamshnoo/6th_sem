# %%
import pandas as pd
import numpy as np
import seaborn as sns

y_true = []
for i in range(150):  
    if i in range(0,51):
        y_true.append('Iris-setosa')
    elif i in range(51,101):
        y_true.append('Iris-versicolor')
    else :
        y_true.append('Iris-virginica')
    
data = np.genfromtxt('data/iris.csv', delimiter=',')
df_true = pd.DataFrame({'sepal length': data[:, 0], 'sepal width': data[:, 1], 'petal length': data[:, 2], 'petal width': data[:, 3], 'True class': y_true})
sns.pairplot(df_true, hue='True class', kind='reg')

# %%
sns.pairplot(df_true, kind='reg')

# %%
data = np.genfromtxt('data/iris.csv', delimiter=',')
df_true = pd.DataFrame({'sepal length': data[:, 0], 'sepal width': data[:, 1], 'True class': y_true})
sns.pairplot(df_true, hue='True class', kind='reg')

# %%
sns.pairplot(df_true, kind='reg')
